# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/drive/MyDrive/Virtual Consultant (FYP)/Covid Tabular Data/Covid19For_EDA.csv")
data.shape
# Out:
# (4000, 9)

# %%
data.head()
# Out:
#   cough fever sore_throat shortness_of_breath head_ache corona_result  \
# 0    No    No          No                  No        No      Negative
# 1    No    No          No                  No        No      Negative
# 2    No    No          No                  No        No      Negative
# 3    No    No          No                  No        No      Negative
# 4    No    No          No                  No        No      Negative
#
#   age_60_and_above gender test_indication
# 0               No   Male           Other
# 1               No   Male           Other
# 2               No   Male           Other
# 3               No   Male           Other
# 4               No   Male           Other

# %%
data.isnull().sum()
# Out:
# cough                  0
# fever                  0
# sore_throat            0
# shortness_of_breath    0
# head_ache              0
# corona_result          0
# age_60_and_above       0
# gender                 0
# test_indication        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cough                4000 non-null   object
#  1   fever                4000 non-null   object
#  2   sore_throat          4000 non-null   object
#  3   shortness_of_breath  4000 non-null   object
#  4   head_ache            4000 non-null   object
#  5   corona_result        4000 non-null   object
#  6   age_60_and_above     4000 non-null   object
#  7   gender               4000 non-null   object
#  8   test_indication      4000 non-null   object
# dtypes: object(9)
# memory usage: 281.4+ KB

# %%
data.describe()
# Out:
#        cough fever sore_throat shortness_of_breath head_ache corona_result  \
# count   4000  4000        4000                4000      4000          4000
# unique     2     2           2                   2         2             2
# top       No    No          No                  No        No      Negative
# freq    3571  3488        3789                3913      3590          2000
#
#        age_60_and_above  gender test_indication
# count              4000    4000            4000
# unique                2       2               3
# top                  No  Female           Other
# freq               3487    2018            3040

# %%
data.head()
# Out:
#   cough fever sore_throat shortness_of_breath head_ache corona_result  \
# 0    No    No          No                  No        No      Negative
# 1    No    No          No                  No        No      Negative
# 2    No    No          No                  No        No      Negative
# 3    No    No          No                  No        No      Negative
# 4    No    No          No                  No        No      Negative
#
#   age_60_and_above gender test_indication
# 0               No   Male           Other
# 1               No   Male           Other
# 2               No   Male           Other
# 3               No   Male           Other
# 4               No   Male           Other

# %%
plt.figure(figsize = (8,8))
sns.countplot(x = data["corona_result"])
plt.xlabel("Corona Result")
plt.ylabel("Count")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
fig.subplots_adjust(hspace = 0.4, wspace = 0.4)

plt.subplot(121)
plt.pie(x = data["gender"].value_counts(), labels = ["Female","Male"],autopct='%1.1f%%', startangle=45,explode = [0.1,0.1],textprops={'size': 'x-large'})

plt.subplot(122)
sns.countplot(x = data["gender"])
plt.xlabel("Gender")
plt.ylabel("Count")
plt.savefig("/content/drive/MyDrive/Virtual Consultant (FYP)/Covid Tabular Data/Gender Distribution.png",dpi = 1200)
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
fig.subplots_adjust(hspace = 0.4, wspace = 0.6)

plt.subplot(121)
plt.pie(x = data["test_indication"].value_counts(), labels = ["Other","Contact With Confirmed","Abroad"],autopct='%1.1f%%', startangle=120,explode = [0.1,0.1,0.1],textprops={'size': 'x-large'})

plt.subplot(122)
sns.countplot(x = data["test_indication"])
plt.xlabel("Test Indication")
plt.ylabel("Count")
plt.savefig("/content/drive/MyDrive/Virtual Consultant (FYP)/Covid Tabular Data/Test Indication Distribution.png",dpi = 1200)
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
fig.subplots_adjust(hspace = 0.4, wspace = 0.6)

plt.subplot(121)
plt.pie(x = data["corona_result"].value_counts(), labels = ["Positive","Negative"],autopct='%1.1f%%', startangle=120,explode = [0.1,0.1],textprops={'size': 'x-large'})

plt.subplot(122)
sns.countplot(x = data["corona_result"])
plt.xlabel("Corona Result")
plt.ylabel("Count")
plt.savefig("/content/drive/MyDrive/Virtual Consultant (FYP)/Covid Tabular Data/Corona Result Distribution.png",dpi = 1200)
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
fig.subplots_adjust(hspace = 0.4, wspace = 0.6)

plt.subplot(121)
plt.pie(x = data["cough"].value_counts(), labels = ["No","Yes"],autopct='%1.1f%%', startangle=120,explode = [0.1,0.1],textprops={'size': 'x-large'})

plt.subplot(122)
sns.countplot(x = data["cough"])
plt.xlabel("Cough")
plt.ylabel("Count")
plt.savefig("/content/drive/MyDrive/Virtual Consultant (FYP)/Covid Tabular Data/cough Distribution.png",dpi = 1200)
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
fig.subplots_adjust(hspace = 0.4, wspace = 0.6)

plt.subplot(121)
plt.pie(x = data["age_60_and_above"].value_counts(), labels = ["No","Yes"],autopct='%1.1f%%', startangle=120,explode = [0.1,0.1],textprops={'size': 'x-large'})

plt.subplot(122)
sns.countplot(x = data["age_60_and_above"])
plt.xlabel("Age Above 60")
plt.ylabel("Count")
plt.savefig("/content/drive/MyDrive/Virtual Consultant (FYP)/Covid Tabular Data/Age Above 60 Distribution.png",dpi = 1200)
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
fig.subplots_adjust(hspace = 0.4, wspace = 0.6)

plt.subplot(121)
plt.pie(x = data["head_ache"].value_counts(), labels = ["No","Yes"],autopct='%1.1f%%', startangle=120,explode = [0.1,0.1],textprops={'size': 'x-large'})

plt.subplot(122)
sns.countplot(x = data["head_ache"])
plt.xlabel("Head ache")
plt.ylabel("Count")
plt.savefig("/content/drive/MyDrive/Virtual Consultant (FYP)/Covid Tabular Data/Head ache Distribution.png",dpi = 1200)
plt.show()

# %%
covid_positive = data[data["corona_result"] == "Positive"]
covid_negative = data[data["corona_result"] == "Negative"]

# %%
plt.figure(figsize = (8,8))
plt.pie(x = covid_positive["cough"].value_counts(), labels = ["No","Yes"],autopct='%1.1f%%', startangle=90,explode = [0.0,0.2],textprops={'size': 'x-large'})
plt.plot()
# Out:
# []

# %%
fig = plt.figure(figsize = (15,15))
fig.subplots_adjust(hspace = 0.4, wspace = 0.4)

plt.subplot(1,2,1)
plt.pie(x = covid_negative["test_indication"].value_counts(), labels = ["Other","Contact with confirmed","Abroad"],autopct='%1.1f%%', startangle=90,explode = [0.3,0.4,0.1],textprops={'size': 'x-large'})


plt.plot()
plt.subplot(1,2,2)
plt.pie(x = covid_positive["test_indication"].value_counts(), labels = ["Other","Contact with confirmed","Abroad"],autopct='%1.1f%%', startangle=90,explode = [0.1,0.1,0.1],textprops={'size': 'x-large'})



plt.show()
#plt.savefig("/content/drive/MyDrive/Virtual Consultant (FYP)/Covid Tabular Data/Cough.png",dpi = 1200)
